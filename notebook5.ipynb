# %% [markdown]
# # Magnetic results
# ### BC: derivative of entropy
#
# Here we look for the results on simualtions in which the boundary condition was zero radial derivative in the entropy fluctuations.
# We compare FC and PC simulations at different criticalities.

# %%
import os 
from magic import *

#Paths for simulations and for the folder to store figures
FIGS_DIR = "/Volumes/LaCie/Report_Sims/figs/"
WORK_DIR = "/Volumes/LaCie/Simulations/mhd/"

# Sims w/ constant entropy at the boundaries:
## FC
FC1 = WORK_DIR + 'Nr15Ek5Ra7dS328Pm5-FC_bdsdr_init0'
FC2 = WORK_DIR + 'Nr15Ek5Ra7dS250Pm5-FC_bdsdr_init0'
FC3 = WORK_DIR + 'Nr15Ek5Ra7dS200Pm5-FC_bdsdr_init0'
## PC
PC1 = WORK_DIR + 'Nr15Ek5Ra7dS328Pm5_bdsdr_init0'
PC2 = WORK_DIR + 'Nr15Ek5Ra7dS250Pm5_bdsdr_init0'
PC3 = WORK_DIR + 'Nr15Ek5Ra7dS200Pm5_bdsdr_init0'

# Name of figures
FIGNAME1 = 'FC_'
FIGNAME2 = 'PC_'

# %% [markdown]
# ## Fully convective simulations
#
# - $Ra = 1.5 Ra_\mathrm{c}$

# %%
os.chdir(FC1)
ts1 = MagicTs(field='dipole', all=True, iplot=False)
rad1 = MagicRadial(field='parR', iplot=False)
os.chdir(FIGS_DIR)
it1 = ts1.time.argsort()
plt.plot(ts1.time[it1], ts1.dip_cmb[it1], 'k', label='CMB')
plt.plot(ts1.time[it1], ts1.dipolarity[it1], 'r', label='Total')
plt.ylabel(r'$f_\mathrm{dip}$', fontsize=20)
plt.xlabel(r'$t \; (\tau_\nu)$', fontsize=20)
plt.ylim((0.,1.))
plt.legend(fontsize=15)
plt.title(r'$Ra=1.5 Ra_\mathrm{c}$')
plt.tight_layout()
plt.savefig(FIGNAME1+'1_5rac.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d5850562aa6e> in <module>()
# ----> 1 os.chdir(FC1)
#       2 ts1 = MagicTs(field='dipole', all=True, iplot=False)
#       3 rad1 = MagicRadial(field='parR', iplot=False)
#       4 os.chdir(FIGS_DIR)
#       5 it1 = ts1.time.argsort()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/LaCie/Simulations/mhd/Nr15Ek5Ra7dS328Pm5-FC_bdsdr_init0'

# %% [markdown]
# - $Ra = 2.0 Ra_\mathrm{c}$

# %%
os.chdir(FC2)
ts2 = MagicTs(field='dipole', all=True, iplot=False)
rad2 = MagicRadial(field='parR', iplot=False)
os.chdir(FIGS_DIR)
it2 = ts2.time.argsort()
plt.plot(ts2.time[it2], ts2.dip_cmb[it2], 'k', label='CMB')
plt.plot(ts2.time[it2], ts2.dipolarity[it2], 'r', label='Total')
plt.ylabel(r'$f_\mathrm{dip}$', fontsize=20)
plt.xlabel(r'$t \; (\tau_\nu)$', fontsize=20)
plt.ylim((0.,1.))
plt.title(r'$Ra=2.0 Ra_\mathrm{c}$')
plt.legend(fontsize=15)
plt.tight_layout()
plt.savefig(FIGNAME1+'2_0rac.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-489fd50890f3> in <module>()
# ----> 1 os.chdir(FC2)
#       2 ts2 = MagicTs(field='dipole', all=True, iplot=False)
#       3 rad2 = MagicRadial(field='parR', iplot=False)
#       4 os.chdir(FIGS_DIR)
#       5 it2 = ts2.time.argsort()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/LaCie/Simulations/mhd/Nr15Ek5Ra7dS250Pm5-FC_bdsdr_init0'

# %% [markdown]
# - $Ra = 2.5 Ra_\mathrm{c}$

# %%
os.chdir(FC3)
ts3 = MagicTs(field='dipole', all=True, iplot=False)
rad3 = MagicRadial(field='parR', iplot=False)
os.chdir(FIGS_DIR)
it3 = ts3.time.argsort()
plt.plot(ts3.time[it3], ts3.dip_cmb[it3], 'k', label='CMB')
plt.plot(ts3.time[it3], ts3.dipolarity[it3], 'r', label='Total')
plt.ylabel(r'$f_\mathrm{dip}$', fontsize=20)
plt.xlabel(r'$t \; (\tau_\nu)$', fontsize=20)
plt.ylim((0.,1.))
plt.title(r'$Ra=2.5 Ra_\mathrm{c}$')
plt.legend(fontsize=15)
plt.tight_layout()
plt.savefig(FIGNAME1+'2_5rac.png')
plt.show()

# %% [markdown]
# ## Partly convective simulations
#
# - $Ra = 1.5 Ra_\mathrm{c}$

# %%
os.chdir(PC1)
ts1_pc = MagicTs(field='dipole', all=True, iplot=False)
rad1_pc = MagicRadial(field='parR', iplot=False)
os.chdir(FIGS_DIR)
it1_pc = ts1_pc.time.argsort()
plt.plot(ts1_pc.time[it1_pc], ts1_pc.dip_cmb[it1_pc], 'k', label='CMB')
plt.plot(ts1_pc.time[it1_pc], ts1_pc.dipolarity[it1_pc], 'r', label='Total')
plt.ylabel(r'$f_\mathrm{dip}$', fontsize=20)
plt.xlabel(r'$t \; (\tau_\nu)$', fontsize=20)
plt.ylim((0.,1.))
plt.title(r'$Ra=1.5 Ra_\mathrm{c}$')
plt.legend(fontsize=15)
plt.tight_layout()
plt.savefig(FIGNAME2+'1_5rac.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-4ace48efad8d> in <module>()
# ----> 1 os.chdir(PC1)
#       2 ts1_pc = MagicTs(field='dipole', all=True, iplot=False)
#       3 rad1_pc = MagicRadial(field='parR', iplot=False)
#       4 os.chdir(FIGS_DIR)
#       5 it1_pc = ts1_pc.time.argsort()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/LaCie/Simulations/mhd/Nr15Ek5Ra7dS328Pm5_bdsdr_init0'

# %% [markdown]
# - $Ra = 2.0 Ra_\mathrm{c}$

# %%
os.chdir(PC2)
ts2_pc = MagicTs(field='dipole', all=True, iplot=False)
rad2_pc = MagicRadial(field='parR', iplot=False)
os.chdir(FIGS_DIR)
it2_pc = ts2_pc.time.argsort()
plt.plot(ts2_pc.time[it2_pc], ts2_pc.dip_cmb[it2_pc], 'k', label='CMB')
plt.plot(ts2_pc.time[it2_pc], ts2_pc.dipolarity[it2_pc], 'r', label='Total')
plt.ylabel(r'$f_\mathrm{dip}$', fontsize=20)
plt.xlabel(r'$t \; (\tau_\nu)$', fontsize=20)
plt.ylim((0.,1.))
plt.title(r'$Ra=2.0 Ra_\mathrm{c}$')
plt.legend(fontsize=15)
plt.tight_layout()
plt.savefig(FIGNAME2+'2_0rac.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-d51e6994972d> in <module>()
# ----> 1 os.chdir(PC2)
#       2 ts2_pc = MagicTs(field='dipole', all=True, iplot=False)
#       3 rad2_pc = MagicRadial(field='parR', iplot=False)
#       4 os.chdir(FIGS_DIR)
#       5 it2_pc = ts2_pc.time.argsort()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/LaCie/Simulations/mhd/Nr15Ek5Ra7dS250Pm5_bdsdr_init0'

# %% [markdown]
# - $Ra = 2.5 Ra_\mathrm{c}$

# %%
os.chdir(PC3)
ts3_pc = MagicTs(field='dipole', all=True, iplot=False)
rad3_pc = MagicRadial(field='parR', iplot=False)
os.chdir(FIGS_DIR)
it3_pc = ts3_pc.time.argsort()
plt.plot(ts3_pc.time[it3_pc], ts3_pc.dip_cmb[it3_pc], 'k', label='CMB')
plt.plot(ts3_pc.time[it3_pc], ts3_pc.dipolarity[it3_pc], 'r', label='Total')
plt.ylabel(r'$f_\mathrm{dip}$', fontsize=20)
plt.xlabel(r'$t \; (\tau_\nu)$', fontsize=20)
plt.ylim((0.,1.))
plt.title(r'$Ra=2.5 Ra_\mathrm{c}$')
plt.legend(fontsize=15)
plt.tight_layout()
plt.savefig(FIGNAME2+'2_5rac.png')
plt.show()

# %%
import cmocean
os.chdir(PC3)
s3 = Surf()
s3.surf(field='br', r=1., cm=cmocean.cm.balance, vmin = -1., vmax=1)
print(s3.gr.time)
os.chdir(FIGS_DIR)
plt.savefig(FIGNAME2+'surfB_dsdr.png', dpi=100, transparent=True)
# Out:
# 3.7505264

# %%
# Rescaling to match Gastine et al. 2012, their scale of reference is not the outer radius but the convective shell gap. 
scale = 0.4

os.chdir(FIGS_DIR)
fig, ax = plt.subplots(1,3, figsize=(15,5))
# FC results
ax[0].plot(rad1.radius, rad1.urol/scale, '--k', label='1.5Rac')
ax[0].plot(rad2.radius, rad2.urol/scale, '--r', label='2.0Rac')
ax[0].plot(rad3.radius, rad3.urol/scale, '--b', label='2.5Rac')
# PC results
ax[0].plot(rad1_pc.radius, rad1_pc.urol/scale, 'k')
ax[0].plot(rad2_pc.radius, rad2_pc.urol/scale, 'r')
ax[0].plot(rad3_pc.radius, rad3_pc.urol/scale, 'b')
ax[0].set_ylabel(r'$Ro_\mathrm{l}$', fontsize=20)
ax[0].set_xlabel(r'$r \; (r_\mathrm{o})$', fontsize=20)

# FC results
ax[1].scatter(rad1.urol.mean()/scale, ts1.dip_cmb.mean(), color='k', s=60, label='FC')
ax[1].scatter(rad2.urol.mean()/scale, ts2.dip_cmb.mean(), color='r', s=60)
ax[1].scatter(rad3.urol.mean()/scale, ts3.dip_cmb.mean(), color='b', s=60)
# PC results
ax[1].scatter(rad1_pc.urol[rad1_pc.radius > 0.6].mean()/scale, ts1_pc.dip_cmb.mean(), color='k', marker='s', s=60, label='PC')
ax[1].scatter(rad2_pc.urol[rad2_pc.radius > 0.6].mean()/scale, ts2_pc.dip_cmb.mean(), color='r', marker='s', s=60)
ax[1].scatter(rad3_pc.urol[rad3_pc.radius > 0.6].mean()/scale, ts3_pc.dip_cmb.mean(), color='b', marker='s', s=60)
ax[1].set_ylabel(r'$f_\mathrm{dip}$', fontsize=20)
ax[1].set_xlabel(r'$Ro_\mathrm{l}$', fontsize=20)
ax[1].set_title('CMB', fontsize=20)
ax[1].set_ylim((0.,1.))
ax[1].legend(fontsize=15)


# FC results
ax[2].scatter(rad1.urol.mean()/scale, ts1.dip_l11.mean(), color='k', s=60, label='FC')
ax[2].scatter(rad2.urol.mean()/scale, ts2.dip_l11.mean(), color='r', s=60)
ax[2].scatter(rad3.urol.mean()/scale, ts3.dip_l11.mean(), color='b', s=60)
# PC results
ax[2].scatter(rad1_pc.urol[rad1_pc.radius > 0.6].mean()/scale, ts1_pc.dip_l11.mean(), color='k', marker='s', s=60, label='PC')
ax[2].scatter(rad2_pc.urol[rad2_pc.radius > 0.6].mean()/scale, ts2_pc.dip_l11.mean(), color='r', marker='s', s=60)
ax[2].scatter(rad3_pc.urol[rad3_pc.radius > 0.6].mean()/scale, ts3_pc.dip_l11.mean(), color='b', marker='s', s=60)
ax[2].set_ylabel(r'$f_\mathrm{dip}$', fontsize=20)
ax[2].set_xlabel(r'$Ro_\mathrm{l}$', fontsize=20)
ax[2].set_title(r'$l \leq 11$', fontsize=20)
ax[2].set_ylim((0.,1.))
ax[2].legend(fontsize=15)
plt.tight_layout()
#plt.savefig(FIGNAME2+'.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9bb00b07c42f> in <module>()
#       5 fig, ax = plt.subplots(1,3, figsize=(15,5))
#       6 # FC results
# ----> 7 ax[0].plot(rad1.radius, rad1.urol/scale, '--k', label='1.5Rac')
#       8 ax[0].plot(rad2.radius, rad2.urol/scale, '--r', label='2.0Rac')
#       9 ax[0].plot(rad3.radius, rad3.urol/scale, '--b', label='2.5Rac')
#
# NameError: name 'rad1' is not defined
