# %% [markdown]
# # Kinetic energy staturation at high-Rayleigh
#
# We follow previous papers that study the high-Rayleigh regim in which a saturation was observed for the kinetic energy.
#
# __Wrap-up:__
#
# - _Featerstone et al. (2016a)_: HD and non-rotating simulations; Density and Ra are varied.
#
# - _Featerstone et al. (2016b)_: HD but rotating simulations; Only Rayleigh are varied.
#
# - _Orverdahl et al. (2018)_: Varies Pr and Ra to probe the effect of the Prandtl number in the saturation.
#     - the cutoff Ra that defines the saturation regim varies with Pr (it decreases with lower Pr).
#     - the saturation level of the kinetic energy increases as Pr is reduced.
#
# ## Results

# %%
import numpy as N
import matplotlib.pyplot as P
import pandas as pd
P.style.use(['seaborn-white', 'seaborn-paper', 'seaborn-ticks'])
matplotlib.rc("font", family="Times New Roman", size=12)
matplotlib.rc('xtick', labelsize='medium')
matplotlib.rc('ytick', labelsize='medium')

# %%
#DATA FROM PC AND FC RUNS
sims1= pd.read_csv('./tables/data_results_nrho1.txt', sep=",")
sims1['color'] = sims1['eta'].replace(0.4,'r').replace(0.6,'k')
sims1['symbol'] = sims1['Pr'].replace(1,'d')
sims1['LoFohm'] = N.sqrt(2*sims1['Emag'])/(sims1['OhmDiss']/sims1['BouPower'])**(0.5)

sims15= pd.read_csv('./tables/data_results_nrho15.txt', sep=",")
sims15['color'] = sims15['eta'].replace(0.4,'r').replace(0.6,'k')
sims15['symbol'] = sims15['Pr'].replace(1,'v')
sims15['LoFohm'] = N.sqrt(2*sims15['Emag'])/(sims15['OhmDiss']/sims15['BouPower'])**(0.5)

sims3= pd.read_csv('./tables/data_results_nrho3.txt', sep=",")
sims3['color'] = sims3['eta'].replace(0.4,'r').replace(0.6,'k')
sims3['symbol'] = sims3['Pr'].replace(1,'p')
sims3['LoFohm'] = N.sqrt(2*sims3['Emag'])/(sims3['OhmDiss']/sims3['BouPower'])**(0.5)

# %%
fig, (ax1, ax2, ax3, ax4) = P.subplots(1,4, figsize=(24,4))
ax1.scatter(sims3['Rac'], sims3['Ekin'], c=sims3['color'], marker='p', s=80)
ax1.scatter(sims15['Rac'], sims15['Ekin'], c=sims15['color'], marker='v', s=80)
ax1.scatter(sims1['Rac'], sims1['Ekin'], c=sims1['color'], marker='d', s=80)
#ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_ylim((1.e4, 2.e7))
ax1.set_xlabel('Ra (Ra$_\mathrm{c}$)', fontsize='large')
ax1.set_ylabel(r'$E_\mathrm{K}$', fontsize='large')

ax2.scatter(sims3['Rac'], sims3['ViscDiss'], c=sims3['color'], marker='p', s=80)
ax2.scatter(sims15['Rac'], sims15['ViscDiss'], c=sims15['color'], marker='v', s=80)
ax2.scatter(sims1['Rac'], sims1['ViscDiss'], c=sims1['color'], marker='d', s=80)
ax2.set_yscale('log')
ax2.set_ylim((1.e7, 1.e12))
ax2.set_xlabel('Ra (Ra$_\mathrm{c}$)', fontsize='large')
ax2.set_ylabel(r'$ \sigma^2$', fontsize='large')
ax2.set_title('Viscous Dissipation', fontsize='large')


ax3.scatter(sims3['Rac'], sims3['OhmDiss'], c=sims3['color'], marker='p', s=80)
ax3.scatter(sims15['Rac'], sims15['OhmDiss'], c=sims15['color'], marker='v', s=80)
ax3.scatter(sims1['Rac'], sims1['OhmDiss'], c=sims1['color'], marker='d', s=80)
ax3.set_xlabel('Ra (Ra$_\mathrm{c}$)', fontsize='large')
ax3.set_yscale('log')
ax3.set_ylim((1.e7, 1.e12))
ax3.set_ylabel(r'$(\nabla \times B)^2$', fontsize='large')
ax3.set_title('Ohmic Dissipation', fontsize='large')

ax4.scatter(sims3['Rac'], sims3['BouPower'], c=sims3['color'], marker='p', s=80)
ax4.scatter(sims15['Rac'], sims15['BouPower'], c=sims15['color'], marker='v', s=80)
ax4.scatter(sims1['Rac'], sims1['BouPower'], c=sims1['color'], marker='d', s=80)
ax4.set_xlabel(r'Ra (Ra$_\mathrm{c}$)', fontsize='large')
ax4.set_ylabel(r'$\mathcal{P}$', fontsize='large')
ax4.set_title('Boyancy Power', fontsize='large')
ax4.set_yscale('log')
ax4.set_ylim((1.e7, 1.e12))
# Out:
# (10000000.0, 1000000000000.0)

# %% [markdown]
# The figure above shows several quantities as a function of the Rayleigh number. We chose to express the later in terms of the critical Rayleigh, which determines the minimum value necessary to drive convection in the system, because this criticality varies with the density constrast and with the setup adopted for $\frac{d\bar{s}}{dr}$ (i.e., either fully convective or partially convective in this work).
#
# - Our set of simulations display the saturation behaviour preivously reported in the literature for HD simulations.
#
# - This find suggests that dissipative effects due to the magnetic field present the saturation behaviour for high-Rayleigh numbers (3rd panel).
#
# $$\mathrm{Ra} = \frac{g_\mathrm{o} r_\mathrm{o}^4}{c_\mathrm{p}\kappa\nu} \left| \frac{d\bar{s}}{dr} \right|_{r_\mathrm{o}}, \ \ \ \ \mathrm{Pr} = \frac{\nu}{\kappa}, \ \ \ \ \mathrm{Pm} = \frac{\nu}{\eta}, \ \ \ \ \text{and}  \ \ \ \ \mathrm{Ek} = \frac{\nu}{\Omega r_\mathrm{o}^2} $$
#
#
# \begin{equation}
# Rm = \frac{u_\mathrm{rms} r_\mathrm{o}}{\eta}
# \end{equation}

# %%
fig, (ax1, ax2, ax3, ax4) = P.subplots(1,4, figsize=(24,4))
ax1.scatter(sims3['Rac'], sims3['Ekin'], c=sims3['color'], marker='p', s=80)
ax1.scatter(sims15['Rac'], sims15['Ekin'], c=sims15['color'], marker='v', s=80)
ax1.scatter(sims1['Rac'], sims1['Ekin'], c=sims1['color'], marker='d', s=80)
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_ylim((1.e4, 2.e7))
ax1.set_xlabel('Ra (Ra$_\mathrm{c}$)', fontsize='large')
ax1.set_ylabel(r'$E_\mathrm{K}$', fontsize='large')

ax2.scatter(sims3['Rac'], sims3['ViscDiss'], c=sims3['color'], marker='p', s=80)
ax2.scatter(sims15['Rac'], sims15['ViscDiss'], c=sims15['color'], marker='v', s=80)
ax2.scatter(sims1['Rac'], sims1['ViscDiss'], c=sims1['color'], marker='d', s=80)
ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_ylim((1.e7, 1.e12))
ax2.set_xlabel('Ra (Ra$_\mathrm{c}$)', fontsize='large')
ax2.set_ylabel(r'$ \sigma^2$', fontsize='large')
ax2.set_title('Viscous Dissipation', fontsize='large')


ax3.scatter(sims3['Rac'], sims3['OhmDiss'], c=sims3['color'], marker='p', s=80)
ax3.scatter(sims15['Rac'], sims15['OhmDiss'], c=sims15['color'], marker='v', s=80)
ax3.scatter(sims1['Rac'], sims1['OhmDiss'], c=sims1['color'], marker='d', s=80)
ax3.set_xlabel('Ra (Ra$_\mathrm{c}$)', fontsize='large')
ax3.set_xscale('log')
ax3.set_yscale('log')
ax3.set_ylim((1.e7, 1.e12))
ax3.set_ylabel(r'$(\nabla \times B)^2$', fontsize='large')
ax3.set_title('Ohmic Dissipation', fontsize='large')

ax4.scatter(sims3['Rac'], sims3['BouPower'], c=sims3['color'], marker='p', s=80)
ax4.scatter(sims15['Rac'], sims15['BouPower'], c=sims15['color'], marker='v', s=80)
ax4.scatter(sims1['Rac'], sims1['BouPower'], c=sims1['color'], marker='d', s=80)
ax4.set_xlabel(r'Ra (Ra$_\mathrm{c}$)', fontsize='large')
ax4.set_ylabel(r'$\mathcal{P}$', fontsize='large')
ax4.set_title('Boyancy Power', fontsize='large')
ax4.set_xscale('log')
ax4.set_yscale('log')
ax4.set_ylim((1.e7, 1.e12))
# Out:
# (10000000.0, 1000000000000.0)

# %%
fig, (ax1, ax2) = P.subplots(1,2, figsize=(12,4))

ax1.scatter(sims3['Rac'], sims3['ViscDiss']/sims3['BouPower'], c=sims3['color'], marker='p', s=80)
ax1.scatter(sims15['Rac'], sims15['ViscDiss']/sims15['BouPower'], c=sims15['color'], marker='v', s=80)
ax1.scatter(sims1['Rac'], sims1['ViscDiss']/sims1['BouPower'], c=sims1['color'], marker='d', s=80)
ax1.set_xlabel(r'Ra (Ra$_\mathrm{c}$)', fontsize='large')
ax1.set_ylabel(r'$\mathcal{F}_\mathrm{visc}$', fontsize='large', rotation=90)
ax1.set_title('Viscous faction', fontsize='large')
ax1.set_ylim((0.,1.))

ax2.scatter(sims3['Rac'], sims3['OhmDiss']/sims3['BouPower'], c=sims3['color'], marker='p', s=80)
ax2.scatter(sims15['Rac'], sims15['OhmDiss']/sims15['BouPower'], c=sims15['color'], marker='v', s=80)
ax2.scatter(sims1['Rac'], sims1['OhmDiss']/sims1['BouPower'], c=sims1['color'], marker='d', s=80)
ax2.set_xlabel(r'Ra (Ra$_\mathrm{c}$)', fontsize='large')
ax2.set_ylabel(r'$\mathcal{F}_\mathrm{ohm}$', fontsize='large', rotation=90)
ax2.set_title('Ohmic faction', fontsize='large')
ax2.set_ylim((0.,1.))
# Out:
# (0.0, 1.0)

# %%
fig, (ax1, ax2, ax3) = P.subplots(1,3, figsize=(18,4))
ax1.scatter(sims3['ViscDiss'], sims3['BouPower'], c=sims3['color'], marker='p', s=80)
ax1.scatter(sims15['ViscDiss'], sims15['BouPower'], c=sims15['color'], marker='v', s=80)
ax1.scatter(sims1['ViscDiss'], sims1['BouPower'], c=sims1['color'], marker='d', s=80)
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlim((1.e7,5.e11))
ax1.set_ylim((1.e7,5.e11))
ax1.set_xlabel(r'$ \sigma^2$', fontsize='large')
ax1.set_ylabel(r'$\mathcal{P}$', fontsize='large')
ax1.set_title('Viscous Dissipation vs Bouyancy Power', fontsize='large')
ax1.plot(10**N.arange(7,13), 10**N.arange(7,13), 'k--', alpha=2./3)


ax2.scatter(sims3['OhmDiss'], sims3['BouPower'], c=sims3['color'], marker='p', s=80)
ax2.scatter(sims15['OhmDiss'], sims15['BouPower'], c=sims15['color'], marker='v', s=80)
ax2.scatter(sims1['OhmDiss'], sims1['BouPower'], c=sims1['color'], marker='d', s=80)
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlim((1.e7,5.e11))
ax2.set_ylim((1.e7,5.e11))
ax2.set_xlabel(r'$(\nabla \times B)^2$', fontsize='large')
ax2.set_ylabel(r'$\mathcal{P}$', fontsize='large')
ax2.set_title('Ohmic Dissipation vs Bouyancy Power', fontsize='large')
ax2.plot(10**N.arange(7,13), 10**N.arange(7,13), 'k--', alpha=2./3)



ax3.scatter(sims3['ViscDiss'], sims3['OhmDiss'], c=sims3['color'], marker='p', s=80)
ax3.scatter(sims15['ViscDiss'], sims15['OhmDiss'], c=sims15['color'], marker='v', s=80)
ax3.scatter(sims1['ViscDiss'], sims1['OhmDiss'], c=sims1['color'], marker='d', s=80)
ax3.set_xscale('log')
ax3.set_yscale('log')
ax3.set_xlim((1.e7,5.e11))
ax3.set_ylim((1.e7,5.e11))
ax3.set_xlabel(r'$ \sigma^2$', fontsize='large')
ax3.set_ylabel(r'$(\nabla \times B)^2$', fontsize='large')
ax3.set_title('Viscous vs Ohmic Dissipation', fontsize='large')
ax3.plot(10**N.arange(7,13), 10**N.arange(7,13), 'k--', alpha=2./3)

# %%
P.scatter(sims3['Rac'], sims3['LoFohm'], c=sims3['color'], marker='p', s=80)
P.scatter(sims15['Rac'], sims15['LoFohm'], c=sims15['color'], marker='v', s=80)
P.scatter(sims1['Rac'],sims1['LoFohm'], c=sims1['color'], marker='d', s=80)
P.yscale('log')
P.xlabel(r'Ra (Ra$_\mathrm{c}$)', fontsize='large', labelpad=20.)
P.ylabel(r'$\frac{\mathrm{Lo}}{\sqrt{\mathcal{F}_\mathrm{ohm}}}$', fontsize=20, rotation=0, labelpad=30.)
# Out:
# Text(0,0.5,'$\\frac{\\mathrm{Lo}}{\\sqrt{\\mathcal{F}_\\mathrm{ohm}}}$')

# %%
P.scatter(sims3['BouPower'], sims3['LoFohm'], c=sims3['color'], marker='p', s=80)
P.scatter(sims15['BouPower'], sims15['LoFohm'], c=sims15['color'], marker='v', s=80)
P.scatter(sims1['BouPower'],sims1['LoFohm'], c=sims1['color'], marker='d', s=80)
P.xscale('log')
P.yscale('log')
P.xlim((1.e8,4.e11))
P.ylim((1.e2,1.e4))
P.xlabel(r'$\mathcal{P}$', fontsize='large')
P.ylabel(r'$\frac{\mathrm{Lo}}{\sqrt{\mathcal{F}_\mathrm{ohm}}}$', fontsize=20, rotation=0, labelpad=30.)
# Out:
# Text(0,0.5,'$\\frac{\\mathrm{Lo}}{\\sqrt{\\mathcal{F}_\\mathrm{ohm}}}$')

# %%
P.scatter(sims3['BouPower'], sims3['Ro'], c=sims3['color'], marker='p', s=80)
P.scatter(sims15['BouPower'], sims15['Ro'], c=sims15['color'], marker='v', s=80)
P.scatter(sims1['BouPower'],sims1['Ro'], c=sims1['color'], marker='d', s=80)
P.xscale('log')
P.yscale('log')
P.xlim((1.e8,2.e11))
P.ylim((5.e-3,3.e-1))
P.xlabel(r'$\mathcal{P}$', fontsize='large')
P.ylabel('Ro', fontsize='large')
P.title('Bouyancy Power vs Rossby number', fontsize='large')
# Out:
# Text(0.5,1,'Bouyancy Power vs Rossby number')

# %%
P.scatter(sims3['Rac'], sims3['BouPower']/(sims3['ViscDiss']+sims3['OhmDiss']), c=sims3['color'], marker='p', s=80)
P.scatter(sims15['Rac'], sims15['BouPower']/(sims15['ViscDiss']+sims15['OhmDiss']), c=sims15['color'], marker='v', s=80)
P.scatter(sims1['Rac'], sims1['BouPower']/(sims1['ViscDiss']+sims1['OhmDiss']), c=sims1['color'], marker='d', s=80)
P.xscale('log')
P.ylabel(r'$\mathcal{P}/(\sigma + \eta)$', fontsize='large')
P.xlabel('Ra (Rac)', fontsize='large')
P.title('Bouyancy Power vs Rossby number', fontsize='large')
# Out:
# Text(0.5,1,'Bouyancy Power vs Rossby number')

# %%
sims15['OhmDiss']/sims15['BouPower']
# Out:
# 0     0.162424
# 1     0.288382
# 2     0.265306
# 3     0.410256
# 4     0.307028
# 5     0.272059
# 6     0.458491
# 7     0.488235
# 8     0.457983
# 9     0.600990
# 10    0.530070
# 11    0.677262
# 12    0.586466
# 13    0.761905
# dtype: float64
